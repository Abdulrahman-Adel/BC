# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(20,10))

# %matplotlib inline

# %%
df = pd.read_csv("training.csv",delimiter = ";",decimal=",")
df_val = pd.read_csv("validation.csv",delimiter = ";",decimal=",")

# %%
sns.countplot(x="classLabel",data=df)

# %%
sns.countplot(x="classLabel",data=df_val)

# %%
sns.relplot(x="variable14",y="variable17",data=df,hue="classLabel")

# %%
sns.countplot(x="variable6",data=df,hue="classLabel")

# %%
sns.countplot(x="variable7",data=df,hue="classLabel")

# %%
sns.countplot(x="variable5",data=df,hue="classLabel")

# %%
sns.catplot(x="variable7",y="variable17",data=df,kind="box")

# %%
categorical_cols = [col for col in df.columns if df[col].dtype == "object"]

categorical_corr = df[categorical_cols].apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)

sns.heatmap(categorical_corr,linewidth=0.5)

# %%
categorical_corr = df_val[categorical_cols].apply(lambda x : pd.factorize(x)[0]).corr(method='pearson', min_periods=1)

sns.heatmap(categorical_corr,linewidth=0.5)

# %%
df["classLabel"] = df["classLabel"].replace("no.",0).replace("yes.",1)
df_val["classLabel"] = df_val["classLabel"].replace("no.",0).replace("yes.",1)

# %%
sns.heatmap(df.corr(),linewidth=0.5)

# %%
X = pd.read_csv("X_cleaned.csv")

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = None)

X = pca.fit_transform(X)

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
# Out:
# Text(0, 0.5, 'cumulative explained variance')
